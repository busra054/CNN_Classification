# %% [markdown]
# **CNN kullanarak X-RAY görüntülerinden Akciğer Hastalığı tespiti**
# **Dataset Bilgileri**
# Akciğer Hastalıklarının Tespiti Gerekliliği:
#
# Akciğer hastalıklarının tespiti birkaç nedenden dolayı hayati önem taşır:
#
# **Erken Müdahale:** Erken teşhis, zamanında tıbbi müdahale ve tedaviye olanak sağlayarak başarılı yönetim ve iyileşme şansını artırır.
#
# **Hastalık Sınıflandırması:** Zatürre, tüberküloz ve akciğer kanseri gibi çeşitli akciğer hastalıkları arasındaki ayrımı yapmak, uygun tedavi planlaması için çok önemlidir.
#
# **Halk Sağlığı:** Etkili hastalık tespiti ve yönetimi, genel hastalık yükünü azaltarak halk sağlığı üzerinde olumlu bir etki yaratabilir.
#
# **Akciğer X-Ray Görüntü Veri Seti:**
#
# "Akciğer Röntgen Görüntü Veri Seti", akciğer hastalıklarının tespiti ve teşhisinde önemli rol oynayan kapsamlı bir röntgen görüntüleri koleksiyonudur. Bu veri seti, hastaneler, klinikler ve sağlık kurumları dahil olmak üzere çeşitli kaynaklardan titizlikle toplanan çok sayıda yüksek kaliteli röntgen görüntüsü içermektedir.
#
# **Veri Seti İçeriği:**
#
# Toplam Görüntü Sayısı: Veri seti toplam 3.475 X-ışını görüntüsünden oluşmaktadır. Veri Setindeki Sınıflar:
#
# **Normal (1250 Görüntü):** Bu görüntüler sağlıklı akciğer durumlarını temsil eder ve tanı prosedürlerinde karşılaştırma için referans görevi görür.
#
# **Akciğer Opaklığı (1125 Görüntü):** Bu sınıf, çeşitli derecelerdeki akciğer anormalliklerini gösteren X-ışını görüntülerini içerir ve analiz için çeşitli vakalar sağlar.
#
# **Viral Pnömoni (1100 Görsel):** Bu kategorideki görseller viral pnömoni vakalarıyla ilişkilendirilmiş olup, bu spesifik akciğer enfeksiyonunun anlaşılmasına ve tanımlanmasına katkıda bulunmaktadır.
#
# Sonuç olarak, "Akciğer Röntgen Görüntü Veri Seti", akciğer hastalıklarının tespiti, sınıflandırılması ve anlaşılmasını destekleyen çeşitli ve iyi belgelenmiş bir röntgen görüntüleri koleksiyonu sunarak sağlık sektöründe önemli bir rol oynamaktadır. Bu kaynak, solunum tıbbı alanının ilerlemesinde ve hasta sonuçlarının iyileştirilmesinde etkilidir.

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fatemehmehrparvar/lung-disease")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 34.9M/34.9M [00:02<00:00, 14.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fatemehmehrparvar/lung-disease/versions/1

# %%
lung_opacity_path = os.path.join(path, "Lung X-Ray Image", "Lung X-Ray Image", "Lung_Opacity")
normal_path = os.path.join(path, "Lung X-Ray Image", "Lung X-Ray Image", "Normal")
viral_pneumonia_path = os.path.join(path, "Lung X-Ray Image", "Lung X-Ray Image", "Viral Pneumonia")

# %% [markdown]
# Data Visualization

# %%
# ---------------- Function to load sample images ----------------
def load_samples(path, num_samples=5):
    files = os.listdir(path)[:num_samples]
    images = [Image.open(os.path.join(path, f)) for f in files]
    return images

# Load 5 sample images from each class
lung_opacity_imgs = load_samples(lung_opacity_path)
normal_imgs = load_samples(normal_path)
viral_pneumonia_imgs = load_samples(viral_pneumonia_path)

# ---------------- Plotting ----------------
fig, axes = plt.subplots(3, 5, figsize=(15, 9))

# Row 1: Lung Opacity
for i, img in enumerate(lung_opacity_imgs):
    axes[0, i].imshow(img, cmap='gray')
    axes[0, i].axis('off')
    if i == 2:
        axes[0, i].set_title("Lung Opacity",fontsize=18, fontweight='bold')

# Row 2: Normal
for i, img in enumerate(normal_imgs):
    axes[1, i].imshow(img, cmap='gray')
    axes[1, i].axis('off')
    if i == 2:
        axes[1, i].set_title("Normal",fontsize=18, fontweight='bold')

# Row 3: Viral Pneumonia
for i, img in enumerate(viral_pneumonia_imgs):
    axes[2, i].imshow(img, cmap='gray')
    axes[2, i].axis('off')
    if i == 2:
        axes[2, i].set_title("Viral Pneumonia", fontsize=18, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import os

# ---------------- Count images using existing paths ----------------
class_counts = {
    "Lung Opacity": len(os.listdir(lung_opacity_path)),
    "Normal": len(os.listdir(normal_path)),
    "Viral Pneumonia": len(os.listdir(viral_pneumonia_path))
}

# Print counts
for cls, count in class_counts.items():
    print(f"{cls}: {count} images")

# ---------------- Plot bar chart ----------------
plt.figure(figsize=(8,6))
bars = plt.bar(class_counts.keys(), class_counts.values(), color=['orange', 'green', 'red'])

# Title and labels with bold font and increased size
plt.title("Number of Images per Class", fontsize=18, fontweight='bold')
plt.ylabel("Image Count", fontsize=14, fontweight='bold')
plt.xlabel("Classes", fontsize=14, fontweight='bold')

# Bold and increase tick labels
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

# Optionally add value labels on top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 5, yval, ha='center', fontsize=12, fontweight='bold')

plt.show()
# Out:
# Lung Opacity: 1125 images
# Normal: 1250 images
# Viral Pneumonia: 1100 images

# %% [markdown]
# Preprocessing

# %%
import os
from PIL import Image
import numpy as np

# ---------------- Parameters ----------------
target_size = (224, 224)  # resize size
output_base_path = "/content/preprocessed_images"

# Make class folders in output directory
os.makedirs(output_base_path, exist_ok=True)
class_paths = {
    "Lung_Opacity": lung_opacity_path,
    "Normal": normal_path,
    "Viral_Pneumonia": viral_pneumonia_path
}

for cls in class_paths.keys():
    os.makedirs(os.path.join(output_base_path, cls), exist_ok=True)

# ---------------- Preprocessing Function ----------------
def preprocess_and_save(input_path, output_path, target_size):
    files = os.listdir(input_path)
    for f in files:
        try:
            img = Image.open(os.path.join(input_path, f)).convert('L')  # convert to grayscale
            img = img.resize(target_size)  # resize

            # Normalize pixels to [0,1]
            img_array = np.array(img) / 255.0
            img_array = (img_array * 255).astype(np.uint8)  # convert back to uint8 for saving

            # Save processed image
            img_processed = Image.fromarray(img_array)
            save_path = os.path.join(output_path, f)
            img_processed.save(save_path)
        except Exception as e:
            print(f"Error processing {f}: {e}")

# ---------------- Process all classes ----------------
for cls, path in class_paths.items():
    print(f"Processing class: {cls}")
    preprocess_and_save(path, os.path.join(output_base_path, cls), target_size)

print("All images preprocessed and saved successfully!")
# Out:
# Processing class: Lung_Opacity
# Processing class: Normal
# Processing class: Viral_Pneumonia
# All images preprocessed and saved successfully!

# %%
import matplotlib.pyplot as plt
from PIL import Image
import random
import pandas as pd
import os

# ---------------- Paths ----------------
input_dirs = {
    "Lung Opacity": lung_opacity_path,
    "Normal": normal_path,
    "Viral Pneumonia": viral_pneumonia_path
}

# Assuming output_base_path is defined in a previous cell as '/content/preprocessed_images'
output_dirs = {
    "Lung Opacity": os.path.join(output_base_path, "Lung_Opacity"),
    "Normal": os.path.join(output_base_path, "Normal"),
    "Viral Pneumonia": os.path.join(output_base_path, "Viral_Pneumonia")
}

# ---------------- Function to create a DataFrame of filenames ----------------
def create_df(image_dir, label):
    files = os.listdir(image_dir)
    df = pd.DataFrame({
        'filename': files,
        'labels': [label]*len(files)
    })
    return df

# Create a single DataFrame for all classes
df_lung_opacity = create_df(input_dirs["Lung Opacity"], "Lung Opacity")
df_normal = create_df(input_dirs["Normal"], "Normal")
df_viral = create_df(input_dirs["Viral Pneumonia"], "Viral Pneumonia")
df_csv = pd.concat([df_lung_opacity, df_normal, df_viral], ignore_index=True)

# ---------------- Pick 2 samples per class ----------------
sample_lo = df_csv[df_csv['labels'] == 'Lung Opacity'].sample(2, random_state=42)
sample_n = df_csv[df_csv['labels'] == 'Normal'].sample(2, random_state=42)
sample_vp = df_csv[df_csv['labels'] == 'Viral Pneumonia'].sample(2, random_state=42)

# ---------------- Create figure ----------------
fig, axes = plt.subplots(3, 4, figsize=(12, 9))  # 3 rows (classes), 4 cols (Original+Preprocessed for 2 samples)

# ---------------- Function to show comparison ----------------
def show_comparison(row, row_idx, col_idx, title_class):
    orig_path = os.path.join(input_dirs[title_class], row['filename'])
    pre_path = os.path.join(output_dirs[title_class], row['filename'])

    # Original
    orig = Image.open(orig_path)
    axes[row_idx, col_idx].imshow(orig, cmap='gray')
    axes[row_idx, col_idx].axis('off')
    axes[row_idx, col_idx].set_title(f"{title_class} - Original", fontsize=10, fontweight="bold")

    # Preprocessed
    pre = Image.open(pre_path)
    axes[row_idx, col_idx+1].imshow(pre, cmap='gray')
    axes[row_idx, col_idx+1].axis('off')
    axes[row_idx, col_idx+1].set_title(f"{title_class} - Preprocessed", fontsize=10, fontweight="bold")

# ---------------- Plot rows ----------------
for i, (_, row) in enumerate(sample_lo.iterrows()):
    show_comparison(row, 0, i*2, "Lung Opacity")

for i, (_, row) in enumerate(sample_n.iterrows()):
    show_comparison(row, 1, i*2, "Normal")

for i, (_, row) in enumerate(sample_vp.iterrows()):
    show_comparison(row, 2, i*2, "Viral Pneumonia")

plt.tight_layout()
plt.show()

# %% [markdown]
# Building Simple CNN Model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import os
from sklearn.model_selection import train_test_split

# ---------------- Parameters ----------------
img_size = (224, 224)
batch_size = 32
num_epochs = 10
num_classes = 3
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---------------- Custom Dataset ----------------
class LungXRayDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img = Image.open(self.image_paths[idx]).convert('L')  # grayscale
        if self.transform:
            img = self.transform(img)
        label = self.labels[idx]
        return img, label

# ---------------- Prepare image paths and labels ----------------
def get_image_paths_and_labels(preprocessed_dirs):
    image_paths = []
    labels = []

    for i, (cls, path) in enumerate(preprocessed_dirs.items()):
        for f in os.listdir(path):
            image_paths.append(os.path.join(path, f))
            labels.append(i)
    return image_paths, labels

preprocessed_dirs = {
    "Lung_Opacity":  os.path.join(output_base_path, "Lung_Opacity"),
    "Normal":  os.path.join(output_base_path, "Normal"),
    "Viral_Pneumonia": os.path.join(output_base_path, "Viral_Pneumonia")
}

image_paths, labels = get_image_paths_and_labels(preprocessed_dirs)

# ---------------- Train-Test Split ----------------
train_paths, test_paths, train_labels, test_labels = train_test_split(
    image_paths, labels, test_size=0.2, stratify=labels, random_state=42
)

# ---------------- Transforms ----------------
transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])  # grayscale normalization
])

# ---------------- Datasets and Loaders ----------------
train_dataset = LungXRayDataset(train_paths, train_labels, transform=transform)
test_dataset = LungXRayDataset(test_paths, test_labels, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# ---------------- CNN Model ----------------
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),  # 1 channel
            nn.ReLU(),
            nn.MaxPool2d(2,2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 28 * 28, 256),  # depends on input size
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

model = SimpleCNN(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# ---------------- Initialize lists to store metrics ----------------
train_losses = []
val_losses = []
train_accs = []
val_accs = []

# ---------------- Training Loop with Metric Storage ----------------
for epoch in range(num_epochs):
    # ---------- Training ----------
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss_avg = train_loss / len(train_loader)
    train_acc = 100 * correct_train / total_train

    # ---------- Validation ----------
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss_avg = val_loss / len(test_loader)
    val_acc = 100 * correct_val / total_val

    # ---------- Store metrics ----------
    train_losses.append(train_loss_avg)
    val_losses.append(val_loss_avg)
    train_accs.append(train_acc)
    val_accs.append(val_acc)

    print(f"Epoch [{epoch+1}/{num_epochs}], "
          f"Train Loss: {train_loss_avg:.4f}, Train Acc: {train_acc:.2f}%, "
          f"Val Loss: {val_loss_avg:.4f}, Val Acc: {val_acc:.2f}%")

# ---------------- Final Test Accuracy ----------------
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f"Final Test Accuracy: {test_acc:.2f}%")
# Out:
# Epoch [1/10], Train Loss: 0.6083, Train Acc: 74.24%, Val Loss: 0.3995, Val Acc: 83.60%
# Epoch [2/10], Train Loss: 0.4013, Train Acc: 83.71%, Val Loss: 0.3389, Val Acc: 85.90%
# Epoch [3/10], Train Loss: 0.3368, Train Acc: 86.47%, Val Loss: 0.3199, Val Acc: 88.20%
# Epoch [4/10], Train Loss: 0.2827, Train Acc: 88.13%, Val Loss: 0.3166, Val Acc: 87.91%
# Epoch [5/10], Train Loss: 0.2448, Train Acc: 90.18%, Val Loss: 0.3077, Val Acc: 88.06%
# Epoch [6/10], Train Loss: 0.2254, Train Acc: 90.90%, Val Loss: 0.3286, Val Acc: 88.92%
# Epoch [7/10], Train Loss: 0.1843, Train Acc: 91.65%, Val Loss: 0.3404, Val Acc: 87.91%
# Epoch [8/10], Train Loss: 0.1725, Train Acc: 93.20%, Val Loss: 0.3427, Val Acc: 87.91%
# Epoch [9/10], Train Loss: 0.1397, Train Acc: 94.14%, Val Loss: 0.3562, Val Acc: 88.06%
# Epoch [10/10], Train Loss: 0.1286, Train Acc: 95.00%, Val Loss: 0.4359, Val Acc: 86.33%
# Final Test Accuracy: 86.33%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))

# ---------------- Loss Curve ----------------
plt.subplot(1,2,1)
plt.plot(train_losses, label='Training Loss', marker='o', linewidth=2)
plt.plot(val_losses, label='Validation Loss', marker='o', linewidth=2)
plt.title('Training vs Validation Loss', fontsize=18, fontweight='bold')
plt.xlabel('Epoch', fontsize=14, fontweight='bold')
plt.ylabel('Loss', fontsize=14, fontweight='bold')
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')
plt.legend(loc='best', prop={'size': 14, 'weight': 'bold'}, frameon=True)
plt.grid(True, linestyle='--', alpha=0.6)

# ---------------- Accuracy Curve ----------------
plt.subplot(1,2,2)
plt.plot(train_accs, label='Training Accuracy', marker='o', linewidth=2)
plt.plot(val_accs, label='Validation Accuracy', marker='o', linewidth=2)
plt.title('Training vs Validation Accuracy', fontsize=18, fontweight='bold')
plt.xlabel('Epoch', fontsize=14, fontweight='bold')
plt.ylabel('Accuracy (%)', fontsize=14, fontweight='bold')
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')
plt.legend(loc='best', prop={'size': 14, 'weight': 'bold'}, frameon=True)
plt.grid(True, linestyle='--', alpha=0.6)

# ---------------- Main Title ----------------
plt.suptitle('CNN Model Performance Over Epochs', fontsize=20, fontweight='bold', y=1.03)

plt.tight_layout()
plt.show()

# %% [markdown]
# Sınıflandırma Metrikleri

# %%
from sklearn.metrics import classification_report

# ---------------- Collect All Predictions and Labels ----------------
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# ---------------- Class Names ----------------
class_names = list(preprocessed_dirs.keys())

# ---------------- Classification Report ----------------
report = classification_report(all_labels, all_preds, target_names=class_names)
print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#                  precision    recall  f1-score   support
#
#    Lung_Opacity       0.82      0.83      0.82       225
#          Normal       0.82      0.82      0.82       250
# Viral_Pneumonia       0.97      0.95      0.96       220
#
#        accuracy                           0.86       695
#       macro avg       0.87      0.87      0.87       695
#    weighted avg       0.86      0.86      0.86       695

# %% [markdown]
# Confusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# ---------------- Confusion Matrix ----------------
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Define class names in correct order
class_names = list(preprocessed_dirs.keys())

# Compute confusion matrix
cm = confusion_matrix(all_labels, all_preds)
cm_norm = confusion_matrix(all_labels, all_preds, normalize='true')

# ---------------- Plot Confusion Matrices ----------------
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Non-normalized CM
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0],
            cbar=False, annot_kws={"size": 14, "weight": "bold"})
axes[0].set_title('Confusion Matrix (Counts)', fontsize=18, fontweight='bold')
axes[0].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[0].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[0].set_xticklabels(class_names, fontsize=12, fontweight='bold', rotation=45)
axes[0].set_yticklabels(class_names, fontsize=12, fontweight='bold', rotation=0)

# Normalized CM
sns.heatmap(cm_norm, annot=True, fmt='.2f', cmap='Greens', ax=axes[1],
            cbar=False, annot_kws={"size": 14, "weight": "bold"})
axes[1].set_title('Confusion Matrix (Normalized)', fontsize=18, fontweight='bold')
axes[1].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[1].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[1].set_xticklabels(class_names, fontsize=12, fontweight='bold', rotation=45)
axes[1].set_yticklabels(class_names, fontsize=12, fontweight='bold', rotation=0)

plt.suptitle('CNN Model Confusion Matrices', fontsize=20, fontweight='bold', y=1.03)
plt.tight_layout()
plt.show()

# %% [markdown]
# ROC Curves

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# ---------------- Compute ROC Curve (Class-wise) ----------------
model.eval()
all_probs = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = torch.softmax(outputs, dim=1)
        all_probs.extend(probs.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

all_probs = np.array(all_probs)
all_labels = np.array(all_labels)

# Binarize the labels for multi-class ROC
n_classes = len(class_names)
y_true_bin = label_binarize(all_labels, classes=np.arange(n_classes))

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], all_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------------- Plot ROC Curves ----------------
plt.figure(figsize=(8, 6))
for i, cls in enumerate(class_names):
    plt.plot(fpr[i], tpr[i],
             lw=2, label=f'{cls} (AUC = {roc_auc[i]:.2f})')

# Chance line
plt.plot([0, 1], [0, 1], 'k--', lw=2)

plt.title("Class-wise ROC Curves", fontsize=18, fontweight='bold')
plt.xlabel("False Positive Rate", fontsize=14, fontweight='bold')
plt.ylabel("True Positive Rate", fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# Performans Matrisi

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import numpy as np
import torch.nn.functional as F

# ---------------- Compute Predictions ----------------
model.eval()
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = F.softmax(outputs, dim=1)
        _, preds = torch.max(probs, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

# Convert to numpy arrays
all_labels = np.array(all_labels)
all_preds = np.array(all_preds)
all_probs = np.array(all_probs)

# ---------------- Performance Metrics ----------------
accuracy = accuracy_score(all_labels, all_preds)
precision = precision_score(all_labels, all_preds, average='macro')
recall = recall_score(all_labels, all_preds, average='macro')
f1 = f1_score(all_labels, all_preds, average='macro')
error_rate = 1 - accuracy

# Compute ROC AUC (macro-average for multi-class)
try:
    roc_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr', average='macro')
except ValueError:
    roc_auc = float('nan')  # if ROC can't be computed

# ---------------- Print Results ----------------
print("|Performance Metrics|")
print("=====================")
print(f"Accuracy     : {accuracy:.4f}")
print(f"Precision    : {precision:.4f}")
print(f"Recall       : {recall:.4f}")
print(f"F1-score     : {f1:.4f}")
print(f"Error Rate   : {error_rate:.4f}")
print(f"ROC AUC      : {roc_auc:.4f}")
# Out:
# |Performance Metrics|
# ...
# Accuracy     : 0.8633
# Precision    : 0.8669
# Recall       : 0.8654
# F1-score     : 0.8661
# Error Rate   : 0.1367
# ROC AUC      : 0.9605

# %% [markdown]
# Prediction

# %%
import random
import matplotlib.pyplot as plt
from PIL import Image
import torch
from torchvision import transforms

# ---------------- Define Class Names ----------------
class_names = list(preprocessed_dirs.keys())

# ---------------- Same Transform as Training ----------------
transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])  # same normalization as training
])

# ---------------- Prediction Function ----------------
def predict_image(model, image_path):
    model.eval()
    image = Image.open(image_path).convert('L')
    img_tensor = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = model(img_tensor)
        _, predicted = torch.max(outputs, 1)

    pred_class = class_names[predicted.item()]
    return image, pred_class

# ---------------- Display Predictions ----------------
plt.figure(figsize=(12, 6))

for i, (cls, folder) in enumerate(preprocessed_dirs.items()):
    # Pick a random image from the class folder
    img_file = random.choice(os.listdir(folder))
    img_path = os.path.join(folder, img_file)

    # Predict using the model
    image, pred_class = predict_image(model, img_path)

    # Set title color based on correctness
    color = 'green' if pred_class == cls else 'red'

    # Plot image with labels
    plt.subplot(1, len(preprocessed_dirs), i + 1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.title(f"Actual: {cls}\nPredicted: {pred_class}",
              fontsize=12, fontweight='bold', color=color)

plt.suptitle("Prediction using our trained CNN", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
